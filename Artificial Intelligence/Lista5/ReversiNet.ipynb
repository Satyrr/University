# %%
import torch
from torch import nn
import numpy as np
import pickle
import matplotlib.pyplot as plt

CUDA = False

# %%
def test_error(model, x_test, y_test):
    model.eval()
    y_predicted = model(x_test)
    loss = (y_predicted - y_test).norm()
    
    y_predicted[y_predicted <= 0] = -1 
    y_predicted[y_predicted > 0] = 1 
    err_rate = 100.0 * (y_test != y_predicted).sum()/y_test.size(0)
    
    return err_rate, loss.item()

def batchify(x, y, batch_size=500):
    samples_num = x.size(0)
    perm = np.random.permutation(samples_num)
    x = x[perm]
    y = y[perm]
    
    start = 0
    end = batch_size if samples_num >= batch_size else samples_num
    while start < samples_num:
        yield x[start:end], y[start:end]

        start = end
        end = start + batch_size
        if end > samples_num:
            end = samples_num


class Reversi_net(nn.Module):
    def __init__(self):
        super(Reversi_net, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(128, 1200),
            nn.Dropout(0.5),
            nn.ReLU()
            )
        self.layer2 = nn.Sequential(
            nn.Linear(1200, 200),
            nn.Dropout(0.5),
            nn.ReLU()
            )
        self.fc2 = nn.Linear(200, 1)
        
    def forward(self, x):
        out = x.view(x.size(0), -1)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.fc2(out)
        return out
    
class Reversi_simple_heuristic_net(nn.Module):
    def __init__(self):
        super(Reversi_simple_heuristic_net, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(3, 700),
            nn.Dropout(0.5),
            nn.ReLU()
            )
        self.layer2 = nn.Sequential(
            nn.Linear(700, 400),
            nn.Dropout(0.5),
            nn.ReLU()
            )
        self.fc2 = nn.Linear(400, 1)
        
    def forward(self, x):
        out = x.view(x.size(0), -1)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.fc2(out)
        return out
    
class Reversi_heuristic_net(nn.Module):
    def __init__(self):
        super(Reversi_heuristic_net, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(5, 700),
            nn.Dropout(0.5),
            nn.ReLU()
            )
        self.layer2 = nn.Sequential(
            nn.Linear(700, 400),
            nn.Dropout(0.5),
            nn.ReLU()
            )
        self.fc2 = nn.Linear(400, 1)
        
    def forward(self, x):
        out = x.view(x.size(0), -1)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.fc2(out)
        return out

    
def train(model, x, y, x_test, y_test, epoch_num=10, log_every=5):
    # Use the nn package to define our model and loss function.
    if CUDA:
        model.cuda()
    loss_fn = torch.nn.MSELoss(size_average=True)
    learning_rate = 1e-3
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.99997)
    
    history = {"train_losses":[], "train_errors":[], "test_errors":[], "test_losses":[]}
    iter_ = 0
    try:
        for t in range(epoch_num):
            model.train()
            for x_batch, y_batch in batchify(x, y, 200):
                
                if CUDA:
                    x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
                
                scheduler.step()
                iter_ += 1

                y_pred = model(x_batch)
                loss = loss_fn(y_pred, y_batch)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                y_pred[y_pred <= 0] = -1 
                y_pred[y_pred > 0] = 1 
                err_rate = 100.0 * (y_batch != y_pred).sum()/y_pred.size(0)

                history["train_losses"].append(loss.item()) 
                history["train_errors"].append(err_rate)

                if iter_ % log_every == 0:
                    print "Minibatch {0: >6}  | loss {1: >5.10f} | err rate {2: >5.10f}%" \
                              .format(iter_, loss.item(), err_rate)
    
            test_err, test_loss = test_error(model, x_test, y_test)
            history["test_errors"].append( (iter_, test_err) )
            history["test_losses"].append( (iter_, test_loss) )
            print('After epoch {0}, test_err = {1}, test_loss = {2}'.format(t, test_err, test_loss))
            
    except KeyboardInterrupt:
        pass
        
        return history
    
def print_history(history):
    plt.figure(figsize=(16,10))
    plt.subplot(121)
    plt.plot(history['train_losses'], label='train loss')
    plt.legend()
    
    plt.subplot(122)
    plt.plot(history['train_errors'], label='train error')
    history['test_errors'] = np.array(history['test_errors'])
    plt.plot(history['test_errors'][:,0],history['test_errors'][:,1], label='test error')
    plt.legend()
    plt.show()

# %%
## Load Data
#dataset = open('reversi_learning_data/bigger.dat', 'r')
#dataset = open('reversi_learning_data/smaller.dat', 'r')
dataset = open('mine.dat', 'r')

#####
# Format danych:
# rezultat plansza przewaga_pionkow zajete_rogi zajete_pola_wokol_rogow mobilnosc  
#####


games_X, games_X_heurs, games_Y = [], [], []

for l in dataset:
    board = np.zeros((2,8,8)).astype(float)

    game = l.split(' ')

    min_pieces = [1 if p=='0' else 0 for p in game[1].rstrip()]
    max_pieces = [1 if p=='1' else 0 for p in game[1].rstrip()]

    board[0,:,:] = np.array(min_pieces).reshape(8,8).copy()
    board[1,:,:] = np.array(max_pieces).reshape(8,8).copy()
    board_heurs = np.array([float(val) for val in game[2:]])

    games_X_heurs.append(board_heurs)
    games_X.append(board)
    games_Y.append(int(game[0]))


games_X = np.array(games_X)
games_X_heurs = np.array(games_X_heurs)
games_Y = np.array(games_Y).reshape((-1, 1))
print(games_X_heurs.shape)

x = torch.from_numpy(games_X).float()
x_heurs = torch.from_numpy(games_X_heurs).float()
y = torch.from_numpy(games_Y).float()
del games_X
del games_Y
del games_X_heurs

# 97 % train, 3 % test
split_num = int(0.97*y.size(0))

x_test = x[split_num:]
x_heurs_test = x_heurs[split_num:]
y_test = y[split_num:]

if CUDA:
    x_test = x_test.cuda()
    x_heurs_test = x_heurs_test.cuda()
    y_test = y_test.cuda()

x = x[:split_num]
x_heurs = x_heurs[:split_num]
y = y[:split_num]
# Out:
# (2608581, 5)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7c03ef79831b> in <module>()
#      42
#      43 # 97 % train, 3 % test
# ---> 44 split_num = int(0.97*games_Y.shape[0])
#      45
#      46 x_test = x[split_num:]
#
# NameError: name 'games_Y' is not defined

# %%
###
# parity and corners heuristics
###
model = Reversi_heuristic_net()
history = train(model, x_heurs, y, x_heurs_test, y_test, 500, log_every=30)
print_history(history)
# Out:
# Minibatch     30  | loss 2.3910486698 | err rate 55.0000000000%
# Minibatch     60  | loss 1.1189935207 | err rate 43.0000000000%
# Minibatch     90  | loss 1.0211952925 | err rate 42.0000000000%
# Minibatch    120  | loss 1.0148988962 | err rate 43.0000000000%
# Minibatch    150  | loss 0.9561702013 | err rate 37.0000000000%
# Minibatch    180  | loss 0.9294297695 | err rate 39.0000000000%
# Minibatch    210  | loss 1.0088834763 | err rate 44.0000000000%
# Minibatch    240  | loss 0.9335533381 | err rate 35.0000000000%
# Minibatch    270  | loss 0.9011523724 | err rate 39.0000000000%
# Minibatch    300  | loss 0.8444431424 | err rate 33.0000000000%
# Minibatch    330  | loss 0.9279951453 | err rate 37.0000000000%
# Minibatch    360  | loss 0.8881499767 | err rate 32.0000000000%
# Minibatch    390  | loss 0.9834189415 | err rate 45.0000000000%
# Minibatch    420  | loss 0.8800733685 | err rate 32.0000000000%
# Minibatch    450  | loss 0.9188525677 | err rate 43.0000000000%
# Minibatch    480  | loss 0.9162659645 | err rate 40.0000000000%
# Minibatch    510  | loss 0.9152030349 | err rate 37.0000000000%
# Minibatch    540  | loss 0.9851777554 | err rate 42.0000000000%
# Minibatch    570  | loss 0.9008310437 | err rate 38.0000000000%
# Minibatch    600  | loss 0.9037355781 | err rate 42.0000000000%
# Minibatch    630  | loss 0.9426452518 | err rate 37.0000000000%
# Minibatch    660  | loss 0.8710116744 | err rate 35.0000000000%
# Minibatch    690  | loss 0.8624625206 | err rate 38.0000000000%
# Minibatch    720  | loss 0.9220545292 | err rate 41.0000000000%
# Minibatch    750  | loss 1.0091937780 | err rate 47.0000000000%
# Minibatch    780  | loss 0.8964399099 | err rate 36.0000000000%
# Minibatch    810  | loss 0.9375045300 | err rate 40.0000000000%
# Minibatch    840  | loss 0.8049524426 | err rate 28.0000000000%
# Minibatch    870  | loss 0.9040315747 | err rate 36.0000000000%
# Minibatch    900  | loss 0.9365098476 | err rate 41.0000000000%
# Minibatch    930  | loss 0.8706532121 | err rate 37.0000000000%
# Minibatch    960  | loss 0.8960248828 | err rate 38.0000000000%
# Minibatch    990  | loss 0.8597888350 | err rate 32.0000000000%
# Minibatch   1020  | loss 0.9339601398 | err rate 40.0000000000%
# Minibatch   1050  | loss 0.9918174744 | err rate 44.0000000000%
# Minibatch   1080  | loss 0.9284076095 | err rate 39.0000000000%
# Minibatch   1110  | loss 0.8959149122 | err rate 36.0000000000%
# Minibatch   1140  | loss 0.9667086601 | err rate 42.0000000000%
# Minibatch   1170  | loss 0.9071601033 | err rate 33.0000000000%
# Minibatch   1200  | loss 0.9132575989 | err rate 45.0000000000%
# Minibatch   1230  | loss 0.8717422485 | err rate 36.0000000000%
# Minibatch   1260  | loss 0.8618694544 | err rate 35.0000000000%
# Minibatch   1290  | loss 0.8488475084 | err rate 35.0000000000%
# Minibatch   1320  | loss 0.8595178723 | err rate 34.0000000000%
# Minibatch   1350  | loss 0.8736544251 | err rate 41.0000000000%
# Minibatch   1380  | loss 0.9291098118 | err rate 37.0000000000%
# Minibatch   1410  | loss 0.8439669609 | err rate 35.0000000000%
# Minibatch   1440  | loss 0.9025819302 | err rate 43.0000000000%
# Minibatch   1470  | loss 0.8805803657 | err rate 39.0000000000%
# Minibatch   1500  | loss 0.8846198320 | err rate 40.0000000000%
# Minibatch   1530  | loss 0.9112365246 | err rate 36.0000000000%
# Minibatch   1560  | loss 0.8293102980 | err rate 35.0000000000%
# Minibatch   1590  | loss 0.8921415210 | err rate 39.0000000000%
# Minibatch   1620  | loss 0.8815686107 | err rate 37.0000000000%
# Minibatch   1650  | loss 0.8593115807 | err rate 33.0000000000%
# Minibatch   1680  | loss 0.9508358836 | err rate 45.0000000000%
# Minibatch   1710  | loss 0.9233207703 | err rate 48.0000000000%
# Minibatch   1740  | loss 0.8702079058 | err rate 37.0000000000%
# Minibatch   1770  | loss 0.9226465821 | err rate 34.0000000000%
# Minibatch   1800  | loss 0.8775018454 | err rate 38.0000000000%
# Minibatch   1830  | loss 0.9334110022 | err rate 41.0000000000%
# Minibatch   1860  | loss 0.8699071407 | err rate 33.0000000000%
# Minibatch   1890  | loss 0.8923272491 | err rate 37.0000000000%
# Minibatch   1920  | loss 0.9502779245 | err rate 36.0000000000%
# Minibatch   1950  | loss 0.8941511512 | err rate 38.0000000000%
# Minibatch   1980  | loss 0.9297965765 | err rate 43.0000000000%
# Minibatch   2010  | loss 0.8390517235 | err rate 34.0000000000%
# Minibatch   2040  | loss 0.8744773865 | err rate 39.0000000000%
# Minibatch   2070  | loss 0.8661231399 | err rate 37.0000000000%
# Minibatch   2100  | loss 0.9119680524 | err rate 36.0000000000%
# Minibatch   2130  | loss 0.8791102767 | err rate 37.0000000000%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-14e486fc3845> in <module>()
#       4 model = Reversi_heuristic_net()
#       5 history = train(model, x_heurs, y, x_heurs_test, y_test, 500, log_every=30)
# ----> 6 print_history(history)
#
# <ipython-input-2-1d0b53cacf28> in print_history(history)
#     152     plt.plot(history['train_errors'], label='train error')
#     153     history['test_errors'] = np.array(history['test_errors'])
# --> 154     plt.plot(history['test_errors'][:,0],history['test_errors'][:,1], label='test error')
#     155     plt.legend()
#     156     plt.show()
#
# IndexError: too many indices for array

# %%
model = Reversi_heuristic_net()
history = train(model, x_info, y, x_info_test, y_test, 500, log_every=30)

print_history(history)
#torch.save(model.state_dict(), "heuristic_features")
# Out:
# torch.Size([2530323, 5])
# torch.Size([78258, 5])
# Minibatch     30  | loss 2.2619018555 | err rate 48.0000000000%
# Minibatch     60  | loss 1.1158442497 | err rate 46.0000000000%
# Minibatch     90  | loss 1.0644850731 | err rate 44.0000000000%
# Minibatch    120  | loss 1.0370875597 | err rate 43.0000000000%
# After epoch 0, test_err = 38, test_loss = 272.749694824
# Minibatch    150  | loss 1.0078153610 | err rate 42.0000000000%
# Minibatch    180  | loss 0.9915976524 | err rate 42.0000000000%
# Minibatch    210  | loss 0.9854397178 | err rate 41.0000000000%
# Minibatch    240  | loss 0.9769820571 | err rate 41.0000000000%
# After epoch 1, test_err = 37, test_loss = 270.598846436
# Minibatch    270  | loss 0.9667223692 | err rate 41.0000000000%
# Minibatch    300  | loss 0.9621053934 | err rate 41.0000000000%
# Minibatch    330  | loss 0.9516115189 | err rate 40.0000000000%
# Minibatch    360  | loss 0.9478312731 | err rate 40.0000000000%
# After epoch 2, test_err = 37, test_loss = 268.619293213
# Minibatch    390  | loss 0.9424063563 | err rate 40.0000000000%
# Minibatch    420  | loss 0.9445595741 | err rate 40.0000000000%
# Minibatch    450  | loss 0.9280627966 | err rate 40.0000000000%
# Minibatch    480  | loss 0.9317131042 | err rate 39.0000000000%
# After epoch 3, test_err = 36, test_loss = 266.903839111
# Minibatch    510  | loss 0.9311832190 | err rate 40.0000000000%
# Minibatch    540  | loss 0.9303093553 | err rate 39.0000000000%
# Minibatch    570  | loss 0.9299587607 | err rate 39.0000000000%
# Minibatch    600  | loss 0.9252656102 | err rate 39.0000000000%
# Minibatch    630  | loss 0.9211915731 | err rate 39.0000000000%
# After epoch 4, test_err = 36, test_loss = 265.444396973
# Minibatch    660  | loss 0.9139467478 | err rate 38.0000000000%
# Minibatch    690  | loss 0.9198097587 | err rate 39.0000000000%
# Minibatch    720  | loss 0.9107742310 | err rate 39.0000000000%
# Minibatch    750  | loss 0.9167414308 | err rate 39.0000000000%
# After epoch 5, test_err = 36, test_loss = 263.978210449
# Minibatch    780  | loss 0.9062638879 | err rate 38.0000000000%
# Minibatch    810  | loss 0.9045231342 | err rate 38.0000000000%
# Minibatch    840  | loss 0.9132000804 | err rate 39.0000000000%
# Minibatch    870  | loss 0.9022607207 | err rate 38.0000000000%
# After epoch 6, test_err = 36, test_loss = 263.030456543
# Minibatch    900  | loss 0.9137186408 | err rate 39.0000000000%
# Minibatch    930  | loss 0.9098442197 | err rate 38.0000000000%
# Minibatch    960  | loss 0.9095630050 | err rate 38.0000000000%
# Minibatch    990  | loss 0.9050807357 | err rate 38.0000000000%
# After epoch 7, test_err = 36, test_loss = 262.380950928
# Minibatch   1020  | loss 0.9035555720 | err rate 38.0000000000%
# Minibatch   1050  | loss 0.9050598741 | err rate 38.0000000000%
# Minibatch   1080  | loss 0.9007096887 | err rate 38.0000000000%
# Minibatch   1110  | loss 0.9012665749 | err rate 38.0000000000%
# Minibatch   1140  | loss 0.9019255638 | err rate 38.0000000000%
# After epoch 8, test_err = 36, test_loss = 262.084686279
# Minibatch   1170  | loss 0.9007983208 | err rate 38.0000000000%
# Minibatch   1200  | loss 0.8947054744 | err rate 37.0000000000%
# Minibatch   1230  | loss 0.8968631625 | err rate 38.0000000000%
# Minibatch   1260  | loss 0.8932164907 | err rate 38.0000000000%
# After epoch 9, test_err = 36, test_loss = 261.631896973
# Minibatch   1290  | loss 0.8933440447 | err rate 37.0000000000%
# Minibatch   1320  | loss 0.8947752118 | err rate 37.0000000000%
# Minibatch   1350  | loss 0.8999098539 | err rate 38.0000000000%
# Minibatch   1380  | loss 0.8942254782 | err rate 37.0000000000%
# After epoch 10, test_err = 36, test_loss = 261.054656982
# Minibatch   1410  | loss 0.8942247033 | err rate 38.0000000000%
# Minibatch   1440  | loss 0.8910461068 | err rate 37.0000000000%
# Minibatch   1470  | loss 0.8945359588 | err rate 38.0000000000%
# Minibatch   1500  | loss 0.8845325112 | err rate 37.0000000000%
# After epoch 11, test_err = 36, test_loss = 260.907562256
# Minibatch   1530  | loss 0.8966775537 | err rate 38.0000000000%
# Minibatch   1560  | loss 0.8937980533 | err rate 37.0000000000%
# Minibatch   1590  | loss 0.8879097700 | err rate 37.0000000000%
# Minibatch   1620  | loss 0.8923606277 | err rate 37.0000000000%
# Minibatch   1650  | loss 0.8953130841 | err rate 37.0000000000%
# After epoch 12, test_err = 36, test_loss = 260.830230713
# Minibatch   1680  | loss 0.8888337612 | err rate 37.0000000000%
# Minibatch   1710  | loss 0.8846284151 | err rate 37.0000000000%
# Minibatch   1740  | loss 0.8942325115 | err rate 37.0000000000%
# Minibatch   1770  | loss 0.8961241245 | err rate 38.0000000000%
# After epoch 13, test_err = 36, test_loss = 260.652008057
# Minibatch   1800  | loss 0.8891829252 | err rate 37.0000000000%
# Minibatch   1830  | loss 0.8873200417 | err rate 37.0000000000%
# Minibatch   1860  | loss 0.8957687616 | err rate 37.0000000000%
# Minibatch   1890  | loss 0.8911258578 | err rate 37.0000000000%
# After epoch 14, test_err = 36, test_loss = 260.395263672
# Minibatch   1920  | loss 0.8904137015 | err rate 37.0000000000%
# Minibatch   1950  | loss 0.8926734328 | err rate 38.0000000000%
# Minibatch   1980  | loss 0.8876956105 | err rate 37.0000000000%
# Minibatch   2010  | loss 0.8848711848 | err rate 37.0000000000%
# After epoch 15, test_err = 36, test_loss = 260.199707031
# Minibatch   2040  | loss 0.8926720619 | err rate 38.0000000000%
# Minibatch   2070  | loss 0.8904417157 | err rate 38.0000000000%
# Minibatch   2100  | loss 0.8861693144 | err rate 37.0000000000%
# Minibatch   2130  | loss 0.8842254877 | err rate 37.0000000000%
# After epoch 16, test_err = 36, test_loss = 260.113311768
# Minibatch   2160  | loss 0.8822223544 | err rate 37.0000000000%
# Minibatch   2190  | loss 0.8989020586 | err rate 38.0000000000%
# Minibatch   2220  | loss 0.8849054575 | err rate 37.0000000000%
# Minibatch   2250  | loss 0.8822337985 | err rate 37.0000000000%
# Minibatch   2280  | loss 0.8901020288 | err rate 37.0000000000%
# After epoch 17, test_err = 36, test_loss = 260.168701172
# Minibatch   2310  | loss 0.8910072446 | err rate 38.0000000000%
# Minibatch   2340  | loss 0.8878566623 | err rate 37.0000000000%
# Minibatch   2370  | loss 0.8856424689 | err rate 37.0000000000%
# Minibatch   2400  | loss 0.8927192092 | err rate 38.0000000000%
# After epoch 18, test_err = 36, test_loss = 259.756103516
# Minibatch   2430  | loss 0.8878150582 | err rate 37.0000000000%
# Minibatch   2460  | loss 0.8916364312 | err rate 38.0000000000%
# Minibatch   2490  | loss 0.8879163265 | err rate 37.0000000000%
# Minibatch   2520  | loss 0.8883242011 | err rate 37.0000000000%
# After epoch 19, test_err = 36, test_loss = 259.817962646
# Minibatch   2550  | loss 0.8857377768 | err rate 37.0000000000%
# Minibatch   2580  | loss 0.8826751709 | err rate 37.0000000000%
# Minibatch   2610  | loss 0.8860909939 | err rate 37.0000000000%
# Minibatch   2640  | loss 0.8889753222 | err rate 37.0000000000%
# After epoch 20, test_err = 36, test_loss = 259.731689453
# Minibatch   2670  | loss 0.8861330152 | err rate 37.0000000000%
# Minibatch   2700  | loss 0.8866136670 | err rate 37.0000000000%
# Minibatch   2730  | loss 0.8817440271 | err rate 37.0000000000%
# Minibatch   2760  | loss 0.8861405253 | err rate 38.0000000000%
# Minibatch   2790  | loss 0.8813756704 | err rate 37.0000000000%
# After epoch 21, test_err = 36, test_loss = 259.637145996
# Minibatch   2820  | loss 0.8861180544 | err rate 37.0000000000%
# Minibatch   2850  | loss 0.8869323134 | err rate 38.0000000000%
# Minibatch   2880  | loss 0.8897095919 | err rate 37.0000000000%
# Minibatch   2910  | loss 0.8829910159 | err rate 37.0000000000%
# After epoch 22, test_err = 36, test_loss = 259.622772217
# Minibatch   2940  | loss 0.8873773217 | err rate 37.0000000000%
# Minibatch   2970  | loss 0.8901985288 | err rate 38.0000000000%
# Minibatch   3000  | loss 0.8871991038 | err rate 38.0000000000%
# Minibatch   3030  | loss 0.8802814484 | err rate 37.0000000000%
# After epoch 23, test_err = 36, test_loss = 259.621124268
# Minibatch   3060  | loss 0.8807150126 | err rate 37.0000000000%
# Minibatch   3090  | loss 0.8815140724 | err rate 37.0000000000%
# Minibatch   3120  | loss 0.8866897225 | err rate 37.0000000000%
# Minibatch   3150  | loss 0.8765783906 | err rate 37.0000000000%
# After epoch 24, test_err = 36, test_loss = 259.4402771
# Minibatch   3180  | loss 0.8816251755 | err rate 37.0000000000%
# Minibatch   3210  | loss 0.8849060535 | err rate 37.0000000000%
# Minibatch   3240  | loss 0.8790832162 | err rate 37.0000000000%
# Minibatch   3270  | loss 0.8806597590 | err rate 37.0000000000%
# Minibatch   3300  | loss 0.8814438581 | err rate 37.0000000000%
# After epoch 25, test_err = 36, test_loss = 259.357818604
# Minibatch   3330  | loss 0.8856852651 | err rate 37.0000000000%
# Minibatch   3360  | loss 0.8828589916 | err rate 37.0000000000%
# Minibatch   3390  | loss 0.8878435493 | err rate 38.0000000000%
# Minibatch   3420  | loss 0.8840640783 | err rate 37.0000000000%
# After epoch 26, test_err = 36, test_loss = 259.314025879
# Minibatch   3450  | loss 0.8831543922 | err rate 37.0000000000%
# Minibatch   3480  | loss 0.8834018707 | err rate 37.0000000000%
# Minibatch   3510  | loss 0.8784944415 | err rate 37.0000000000%
# Minibatch   3540  | loss 0.8787916899 | err rate 37.0000000000%
# After epoch 27, test_err = 36, test_loss = 259.208831787
# Minibatch   3570  | loss 0.8769080043 | err rate 37.0000000000%
# Minibatch   3600  | loss 0.8865789771 | err rate 38.0000000000%
# Minibatch   3630  | loss 0.8976602554 | err rate 38.0000000000%
# Minibatch   3660  | loss 0.8852027059 | err rate 37.0000000000%
# After epoch 28, test_err = 36, test_loss = 259.431335449
# Minibatch   3690  | loss 0.8792545199 | err rate 37.0000000000%
# Minibatch   3720  | loss 0.8830074072 | err rate 37.0000000000%
# Minibatch   3750  | loss 0.8838453889 | err rate 37.0000000000%
# Minibatch   3780  | loss 0.8805189729 | err rate 37.0000000000%
# Minibatch   3810  | loss 0.8900446296 | err rate 37.0000000000%
# After epoch 29, test_err = 36, test_loss = 259.201782227
# Minibatch   3840  | loss 0.8828287125 | err rate 37.0000000000%
# Minibatch   3870  | loss 0.8829301596 | err rate 37.0000000000%
# Minibatch   3900  | loss 0.8772287369 | err rate 36.0000000000%
# Minibatch   3930  | loss 0.8786385059 | err rate 37.0000000000%
# After epoch 30, test_err = 36, test_loss = 259.095977783
# Minibatch   3960  | loss 0.8792441487 | err rate 37.0000000000%
# Minibatch   3990  | loss 0.8786447048 | err rate 37.0000000000%
# Minibatch   4020  | loss 0.8821172714 | err rate 37.0000000000%
# Minibatch   4050  | loss 0.8825349808 | err rate 37.0000000000%
# After epoch 31, test_err = 36, test_loss = 259.154266357
# Minibatch   4080  | loss 0.8829344511 | err rate 37.0000000000%
# Minibatch   4110  | loss 0.8803464770 | err rate 37.0000000000%
# Minibatch   4140  | loss 0.8777241111 | err rate 37.0000000000%
# Minibatch   4170  | loss 0.8807631731 | err rate 37.0000000000%
# After epoch 32, test_err = 36, test_loss = 258.909393311
# Minibatch   4200  | loss 0.8823000789 | err rate 37.0000000000%
# Minibatch   4230  | loss 0.8793497086 | err rate 37.0000000000%
# Minibatch   4260  | loss 0.8853622079 | err rate 37.0000000000%
# Minibatch   4290  | loss 0.8805918097 | err rate 37.0000000000%
# After epoch 33, test_err = 36, test_loss = 258.906982422
# Minibatch   4320  | loss 0.8819560409 | err rate 37.0000000000%
# Minibatch   4350  | loss 0.8836165071 | err rate 37.0000000000%
# Minibatch   4380  | loss 0.8802687526 | err rate 37.0000000000%
# Minibatch   4410  | loss 0.8822416067 | err rate 37.0000000000%
# Minibatch   4440  | loss 0.8852294683 | err rate 37.0000000000%
# After epoch 34, test_err = 36, test_loss = 259.012390137
# Minibatch   4470  | loss 0.8768720627 | err rate 37.0000000000%
# Minibatch   4500  | loss 0.8783900142 | err rate 37.0000000000%
# Minibatch   4530  | loss 0.8811655045 | err rate 37.0000000000%
# Minibatch   4560  | loss 0.8785074353 | err rate 37.0000000000%
# After epoch 35, test_err = 36, test_loss = 258.807006836
# Minibatch   4590  | loss 0.8846614957 | err rate 37.0000000000%
# Minibatch   4620  | loss 0.8804708123 | err rate 37.0000000000%
# Minibatch   4650  | loss 0.8740067482 | err rate 36.0000000000%
# Minibatch   4680  | loss 0.8789865375 | err rate 37.0000000000%
# After epoch 36, test_err = 36, test_loss = 258.800720215
# Minibatch   4710  | loss 0.8718009591 | err rate 36.0000000000%
# Minibatch   4740  | loss 0.8846917152 | err rate 37.0000000000%
# Minibatch   4770  | loss 0.8797387481 | err rate 37.0000000000%
# Minibatch   4800  | loss 0.8805202842 | err rate 37.0000000000%
# After epoch 37, test_err = 36, test_loss = 258.766662598
# Minibatch   4830  | loss 0.8893342614 | err rate 38.0000000000%
# Minibatch   4860  | loss 0.8784768581 | err rate 37.0000000000%
# Minibatch   4890  | loss 0.8745071292 | err rate 36.0000000000%
# Minibatch   4920  | loss 0.8824556470 | err rate 37.0000000000%
# Minibatch   4950  | loss 0.8798223734 | err rate 37.0000000000%
# After epoch 38, test_err = 36, test_loss = 259.336181641
# Minibatch   4980  | loss 0.8786600828 | err rate 37.0000000000%
# Minibatch   5010  | loss 0.8765676618 | err rate 37.0000000000%
# Minibatch   5040  | loss 0.8753895760 | err rate 37.0000000000%
# Minibatch   5070  | loss 0.8767359257 | err rate 37.0000000000%
# After epoch 39, test_err = 36, test_loss = 258.77822876
# Minibatch   5100  | loss 0.8790602684 | err rate 37.0000000000%
# Minibatch   5130  | loss 0.8755633831 | err rate 37.0000000000%
# Minibatch   5160  | loss 0.8725802898 | err rate 36.0000000000%
# Minibatch   5190  | loss 0.8823450208 | err rate 37.0000000000%
# After epoch 40, test_err = 36, test_loss = 258.876220703
# Minibatch   5220  | loss 0.8836319447 | err rate 37.0000000000%
# Minibatch   5250  | loss 0.8744745851 | err rate 36.0000000000%
# Minibatch   5280  | loss 0.8773127794 | err rate 37.0000000000%
# Minibatch   5310  | loss 0.8768966794 | err rate 36.0000000000%
# After epoch 41, test_err = 36, test_loss = 258.726257324
# Minibatch   5340  | loss 0.8760669231 | err rate 37.0000000000%
# Minibatch   5370  | loss 0.8778353333 | err rate 37.0000000000%
# Minibatch   5400  | loss 0.8761249781 | err rate 37.0000000000%
# Minibatch   5430  | loss 0.8767367005 | err rate 37.0000000000%
# Minibatch   5460  | loss 0.8747178912 | err rate 36.0000000000%
# After epoch 42, test_err = 35, test_loss = 258.862670898
# Minibatch   5490  | loss 0.8774891496 | err rate 37.0000000000%
# Minibatch   5520  | loss 0.8795775175 | err rate 37.0000000000%
# Minibatch   5550  | loss 0.8793108463 | err rate 37.0000000000%
# Minibatch   5580  | loss 0.8806885481 | err rate 37.0000000000%
# After epoch 43, test_err = 36, test_loss = 258.631439209
# Minibatch   5610  | loss 0.8793920875 | err rate 37.0000000000%
# Minibatch   5640  | loss 0.8812084794 | err rate 37.0000000000%
# Minibatch   5670  | loss 0.8836708069 | err rate 37.0000000000%
# Minibatch   5700  | loss 0.8747776151 | err rate 36.0000000000%
# After epoch 44, test_err = 35, test_loss = 258.702789307
# Minibatch   5730  | loss 0.8851642609 | err rate 37.0000000000%
# Minibatch   5760  | loss 0.8818634748 | err rate 37.0000000000%
# Minibatch   5790  | loss 0.8764874935 | err rate 37.0000000000%
# Minibatch   5820  | loss 0.8804413080 | err rate 37.0000000000%
# After epoch 45, test_err = 36, test_loss = 259.003326416
# Minibatch   5850  | loss 0.8798696399 | err rate 37.0000000000%
# Minibatch   5880  | loss 0.8739304543 | err rate 36.0000000000%
# Minibatch   5910  | loss 0.8778284192 | err rate 37.0000000000%
# Minibatch   5940  | loss 0.8805895448 | err rate 37.0000000000%
# After epoch 46, test_err = 36, test_loss = 258.547546387
# Minibatch   5970  | loss 0.8848945498 | err rate 37.0000000000%
# Minibatch   6000  | loss 0.8700569272 | err rate 36.0000000000%
# Minibatch   6030  | loss 0.8824912906 | err rate 37.0000000000%
# Minibatch   6060  | loss 0.8818461895 | err rate 37.0000000000%
# Minibatch   6090  | loss 0.8787384033 | err rate 37.0000000000%
# After epoch 47, test_err = 35, test_loss = 258.502105713
# Minibatch   6120  | loss 0.8765462041 | err rate 37.0000000000%
# Minibatch   6150  | loss 0.8798124790 | err rate 37.0000000000%
# Minibatch   6180  | loss 0.8758824468 | err rate 37.0000000000%
# Minibatch   6210  | loss 0.8786763549 | err rate 38.0000000000%
# After epoch 48, test_err = 35, test_loss = 258.637939453
# Minibatch   6240  | loss 0.8811414242 | err rate 37.0000000000%
# Minibatch   6270  | loss 0.8767816424 | err rate 36.0000000000%
# Minibatch   6300  | loss 0.8709204793 | err rate 37.0000000000%
# Minibatch   6330  | loss 0.8806770444 | err rate 37.0000000000%
# After epoch 49, test_err = 35, test_loss = 258.523010254
# Minibatch   6360  | loss 0.8719956875 | err rate 37.0000000000%
# Minibatch   6390  | loss 0.8719773293 | err rate 36.0000000000%
# Minibatch   6420  | loss 0.8738411069 | err rate 37.0000000000%
# Minibatch   6450  | loss 0.8800153136 | err rate 37.0000000000%
# After epoch 50, test_err = 35, test_loss = 258.282043457
# Minibatch   6480  | loss 0.8794016838 | err rate 37.0000000000%
# Minibatch   6510  | loss 0.8754703403 | err rate 36.0000000000%
# Minibatch   6540  | loss 0.8752205968 | err rate 36.0000000000%
# Minibatch   6570  | loss 0.8721282482 | err rate 36.0000000000%
# Minibatch   6600  | loss 0.8822481632 | err rate 37.0000000000%
# After epoch 51, test_err = 35, test_loss = 258.669372559
# Minibatch   6630  | loss 0.8831024170 | err rate 37.0000000000%
# Minibatch   6660  | loss 0.8754575253 | err rate 36.0000000000%
# Minibatch   6690  | loss 0.8761076331 | err rate 37.0000000000%
# Minibatch   6720  | loss 0.8795595765 | err rate 37.0000000000%
# After epoch 52, test_err = 35, test_loss = 259.054870605
# Minibatch   6750  | loss 0.8720215559 | err rate 37.0000000000%
# Minibatch   6780  | loss 0.8804673553 | err rate 36.0000000000%
# Minibatch   6810  | loss 0.8781361580 | err rate 37.0000000000%
# Minibatch   6840  | loss 0.8684740067 | err rate 36.0000000000%
# After epoch 53, test_err = 35, test_loss = 258.762695312
# Minibatch   6870  | loss 0.8779587746 | err rate 37.0000000000%
# Minibatch   6900  | loss 0.8801870346 | err rate 37.0000000000%
# Minibatch   6930  | loss 0.8806644678 | err rate 37.0000000000%
# Minibatch   6960  | loss 0.8804017305 | err rate 37.0000000000%
# After epoch 54, test_err = 35, test_loss = 258.554138184
# Minibatch   6990  | loss 0.8658072352 | err rate 36.0000000000%
# Minibatch   7020  | loss 0.8770213723 | err rate 37.0000000000%
# Minibatch   7050  | loss 0.8782265782 | err rate 37.0000000000%
# Minibatch   7080  | loss 0.8753429651 | err rate 36.0000000000%
# Minibatch   7110  | loss 0.8739938736 | err rate 37.0000000000%
# After epoch 55, test_err = 35, test_loss = 258.509307861
# Minibatch   7140  | loss 0.8834723830 | err rate 37.0000000000%
# Minibatch   7170  | loss 0.8776254654 | err rate 37.0000000000%
# Minibatch   7200  | loss 0.8730700016 | err rate 37.0000000000%
# Minibatch   7230  | loss 0.8756102324 | err rate 37.0000000000%
# After epoch 56, test_err = 35, test_loss = 258.168487549
# Minibatch   7260  | loss 0.8773852587 | err rate 37.0000000000%
# Minibatch   7290  | loss 0.8805670142 | err rate 37.0000000000%
# Minibatch   7320  | loss 0.8689319491 | err rate 36.0000000000%
# Minibatch   7350  | loss 0.8760399222 | err rate 37.0000000000%
# After epoch 57, test_err = 35, test_loss = 258.253601074
# Minibatch   7380  | loss 0.8783535361 | err rate 37.0000000000%
# Minibatch   7410  | loss 0.8688101768 | err rate 36.0000000000%
# Minibatch   7440  | loss 0.8678078055 | err rate 36.0000000000%
# Minibatch   7470  | loss 0.8833474517 | err rate 37.0000000000%
# After epoch 58, test_err = 35, test_loss = 258.810699463
# Minibatch   7500  | loss 0.8750974536 | err rate 37.0000000000%
# Minibatch   7530  | loss 0.8835534453 | err rate 37.0000000000%
# Minibatch   7560  | loss 0.8712742329 | err rate 36.0000000000%
# Minibatch   7590  | loss 0.8793859482 | err rate 37.0000000000%
# Minibatch   7620  | loss 0.8782290816 | err rate 36.0000000000%
# After epoch 59, test_err = 35, test_loss = 258.118286133
# Minibatch   7650  | loss 0.8785560727 | err rate 37.0000000000%
# Minibatch   7680  | loss 0.8772104383 | err rate 36.0000000000%
# Minibatch   7710  | loss 0.8755653501 | err rate 37.0000000000%
# Minibatch   7740  | loss 0.8765676022 | err rate 37.0000000000%
# After epoch 60, test_err = 35, test_loss = 258.710113525
# Minibatch   7770  | loss 0.8745456934 | err rate 37.0000000000%
# Minibatch   7800  | loss 0.8728458881 | err rate 36.0000000000%
# Minibatch   7830  | loss 0.8711745143 | err rate 36.0000000000%
# Minibatch   7860  | loss 0.8714892864 | err rate 37.0000000000%
# After epoch 61, test_err = 35, test_loss = 258.19430542
# Minibatch   7890  | loss 0.8751887679 | err rate 37.0000000000%
# Minibatch   7920  | loss 0.8731417060 | err rate 37.0000000000%
