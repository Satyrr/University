# %% [markdown]
# # Assignment 4
#
# **Submission deadline: last lab session before or on Wednesday, 22.11.17**
#
# **Points: 11 + 4 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch.autograd import Variable


class Layer(object):
    
    def train_mode(self):
        """Put layer into training mode.
        """
        self.mode = "train"
    
    def eval_mode(self):
        """Put layer into evalation mode.
        """
        self.mode = "eval"
    
    @property
    def parameters(self):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = Variable(torch.FloatTensor(num_in, num_out),
                          requires_grad=True)
        self.W.name = 'W'
        self.b = Variable(torch.FloatTensor(1, num_out),
                          requires_grad=True)
        self.b.name = 'b'
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    def forward(self, x):
        return x.mm(self.W) + self.b

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x)
    
class DropoutLayer(Layer):
    def forward(self, x):
        if self.mode == "train":
            return torch.nn.functional.dropout(x, 0.5, training=True)
        return torch.nn.functional.dropout(x, 0.5, training=False)
class DropoutLayer20(Layer):
    def forward(self, x):
        if self.mode == "train":
            return torch.nn.functional.dropout(x, 0.2, training=True)
        return torch.nn.functional.dropout(x, 0.2, training=False)
class BatchNormLayer(Layer):
    def __init__(self, num_in):
        self.iter = 0.0
        self.test_u = Variable(torch.Tensor(1, num_in).cuda(), requires_grad=False)
        self.test_sigma = Variable(torch.Tensor(1, num_in).cuda(), requires_grad=False)
        self.gamma = Variable(torch.ones(1, num_in).cuda(), requires_grad=True)
        self.beta = Variable(torch.zeros(1, num_in).cuda(), requires_grad=True)
            
    def forward(self, x):
        if self.mode == "train":
            self.iter += 1.0
            u = torch.mean(x, 0, True)
            sigma_square = torch.mean((x - u) ** 2, 0, True)
            sigma = torch.sqrt(sigma_square + 10e-5)
            
            self.test_u = ( self.test_u*(self.iter-1.0) + u )/self.iter
            self.test_sigma = ( self.test_sigma*(self.iter-1.0) + sigma )/self.iter
        else:
            u = self.test_u
            sigma = self.test_sigma
        return self.beta + self.gamma*(x - u)/sigma
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-d783516d217f> in <module>()
#       1 import numpy as np
#       2 import torch
# ----> 3 import torchsample.transforms as ts
#       4 import torch.nn.functional as F
#       5 from torch.autograd import Variable
#
# build/bdist.linux-x86_64/egg/torchsample/__init__.py in <module>()
#
# build/bdist.linux-x86_64/egg/torchsample/datasets.py in <module>()
#
# ImportError: No module named nibabel

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return torch.mean(-torch.log(torch.gather(
            outputs, 1, targets.unsqueeze(1))))

# %%
from sklearn import datasets
import torchvision


iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """Simple batch gradient descent"""
    try:
        old_loss = np.inf
        x = Variable(torch.from_numpy(x), requires_grad=False)
        y = Variable(torch.from_numpy(y.astype(np.int64)), requires_grad=False)
        model.train_mode()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            for p in model.parameters:
                p.data -= p.grad.data * alpha
                # Zero gradients for the next iteration
                p.grad.data.zero_()

            loss = loss.data[0]
            if old_loss < loss:
                print "Iter: %d, loss increased!" % (i,)
            if (old_loss - loss) < tolerance:
                print "Tolerance level reached. Exiting."
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print "Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}%" \
                      .format(i, loss, err_rate)
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        # p.data.normal_(0, 0.05)
        p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7)
# Out:
# Iteration      0 | loss  1.10 | err rate  70.67%
# Iteration   1000 | loss  0.05 | err rate   2.00%
# Iteration   2000 | loss  0.04 | err rate   2.00%
# Iteration   3000 | loss  0.04 | err rate   1.33%
# Iteration   4000 | loss  0.04 | err rate   1.33%
# Iteration   5000 | loss  0.04 | err rate   1.33%
# Iteration   6000 | loss  0.04 | err rate   1.33%
# Iteration   7000 | loss  0.04 | err rate   1.33%
# Iteration   8000 | loss  0.04 | err rate   1.33%
# Iteration   9000 | loss  0.04 | err rate   1.33%
# Iteration  10000 | loss  0.04 | err rate   1.33%
# Iteration  11000 | loss  0.04 | err rate   1.33%
# Iteration  12000 | loss  0.04 | err rate   1.33%
# Iteration  13000 | loss  0.04 | err rate   1.33%
# Iteration  14000 | loss  0.04 | err rate   1.33%
# Iteration  15000 | loss  0.04 | err rate   1.33%
# Iteration  16000 | loss  0.04 | err rate   1.33%
# Iteration  17000 | loss  0.04 | err rate   1.33%
# Iteration  18000 | loss  0.04 | err rate   1.33%
# Iteration  19000 | loss  0.03 | err rate   1.33%
# Iteration  20000 | loss  0.03 | err rate   1.33%
# Iteration  21000 | loss  0.03 | err rate   1.33%
# Iteration  22000 | loss  0.03 | err rate   1.33%
# Iteration  23000 | loss  0.03 | err rate   1.33%
# Iteration  24000 | loss  0.03 | err rate   1.33%
# Iteration  25000 | loss  0.03 | err rate   1.33%
# Iteration  26000 | loss  0.03 | err rate   1.33%
# Iteration  27000 | loss  0.03 | err rate   1.33%
# Iteration  28000 | loss  0.03 | err rate   1.33%
# Iteration  29000 | loss  0.03 | err rate   1.33%
# Iteration  30000 | loss  0.03 | err rate   1.33%
# Iteration  31000 | loss  0.03 | err rate   1.33%
# Iteration  32000 | loss  0.03 | err rate   1.33%
# Iteration  33000 | loss  0.03 | err rate   0.67%
# Iteration  34000 | loss  0.02 | err rate   0.67%
# Iteration  35000 | loss  0.02 | err rate   0.67%
# Iteration  36000 | loss  0.02 | err rate   0.67%
# Iteration  37000 | loss  0.02 | err rate   0.67%
# Iteration  38000 | loss  0.01 | err rate   0.67%
# Iteration  39000 | loss  0.01 | err rate   0.00%
# Iteration  40000 | loss  0.01 | err rate   0.00%
# Iteration  41000 | loss  0.01 | err rate   0.00%
# Iteration  42000 | loss  0.01 | err rate   0.00%
# Iteration  43000 | loss  0.01 | err rate   0.00%
# Iteration  44000 | loss  0.01 | err rate   0.00%
# Iteration  45000 | loss  0.01 | err rate   0.00%
# Iteration  46000 | loss  0.01 | err rate   0.00%
# Iteration  47000 | loss  0.00 | err rate   0.00%
# Iteration  48000 | loss  0.00 | err rate   0.00%
# Iteration  49000 | loss  0.00 | err rate   0.00%
# Iteration  50000 | loss  0.00 | err rate   0.00%
# Iteration  51000 | loss  0.00 | err rate   0.00%
# Iteration  52000 | loss  0.00 | err rate   0.00%
# Iteration  53000 | loss  0.00 | err rate   0.00%
# Iteration  54000 | loss  0.00 | err rate   0.00%
# Iteration  55000 | loss  0.00 | err rate   0.00%
# Iteration  56000 | loss  0.00 | err rate   0.00%
# Iteration  57000 | loss  0.00 | err rate   0.00%
# Iteration  58000 | loss  0.00 | err rate   0.00%
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import torch
import torchvision
import os

batch_size = 128
data_path = os.environ.get('PYTORCH_DATA_PATH', '../data')

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

# %%
## DATA AUGMENTATION

from PIL import Image
import torch
import torchvision
import os
import numpy as np

batch_size = 128
data_path = os.environ.get('PYTORCH_DATA_PATH', '../data')

crop_transform = torchvision.transforms.Compose(
    [
        #torchvision.transforms.ToTensor(),
        torchvision.transforms.ToPILImage(),
        torchvision.transforms.CenterCrop((20,20)),
        torchvision.transforms.Scale((28,28)),
        torchvision.transforms.ToTensor()
    ])

bright_transform = torchvision.transforms.Compose(
    [
        #torchvision.transforms.ToTensor(),
        torchvision.transforms.ToPILImage(),
        torchvision.transforms.ColorJitter(0.5),
        torchvision.transforms.ToTensor()
    ])

#for cc in torch.Tensor

def augment_data(x):
    x_size = x.size()[0]
    indicies = np.random.randint(x_size, size = x_size/32)
    
    for ind in indicies:
        x[ind] = bright_transform(x[ind])
        plt.figure()
        plt.imshow(x[ind][0].numpy(), cmap="gray")
        #plt.imshow(x[ind][0].numpy(), cmap="hot")
        #img = Image.fromarray(x[ind][0].numpy(), mode='F')

i = 0
for x, y in mnist_loaders['train']:
    i = i + 1
    if i == 2:
        break
    
    augment_data(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-530d9cced4ab> in <module>()
#      23         #torchvision.transforms.ToTensor(),
#      24         torchvision.transforms.ToPILImage(),
# ---> 25         torchvision.transforms.ColorJitter(0.5),
#      26         torchvision.transforms.ToTensor()
#      27     ])
#
# AttributeError: 'module' object has no attribute 'ColorJitter'

# %%
## Without dropout

def compute_error_rate(model, data_loader, cuda=False):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    for x, y in data_loader:
        if cuda:
            x = x.cuda()
            y = y.cuda()
        x = Variable(x.view(x.size(0), -1), volatile=True)
        y = Variable(y, volatile=True)
        outputs = model.forward(x)
        _, predictions = outputs.data.max(dim=1)
        num_errs += (predictions != y.data).sum()
        num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, cuda=False):
    if cuda:
        for p in model.parameters:
            p.data = p.data.cuda()
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    #
    # velocities = 
    #
    velocities = [torch.zeros(param.size()) for param in model.parameters ]
    epsilon = 0.5
    
    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']:
                if cuda:
                    x = x.cuda()
                    y = y.cuda()
                iter_ += 1
                x = Variable(x.view(x.size(0), -1), requires_grad=False)
                y = Variable(y, requires_grad=False)
                
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / out.size(0)

                history['train_losses'].append(loss.data[0])
                history['train_errs'].append(err_rate)
                
                #
                # TODO: Update learning rate
                # Hint: Use the iteration counter i
                # alpha = TODO
                #
                if alpha > 8*1e-3:
                    alpha = alpha*0.99996      
                for p, v in zip(model.parameters, velocities):
                    if p.name == 'W':
                        p.grad.data += p.grad.data*2
                    #
                    # TODO: Implement weight decay addition to gradients
                    # p.grad.data += TODO
                    # 
                    
                    #
                    # TODO: Set the momentum constant 
                    # epsilon = TODO
                    #
                    if iter_ == 100:
                        epsilon = 0.99
                    
                    #
                    # TODO: Implement velocity update in momentum
                    # v[...] = TODO
                    #
                    v = epsilon*v + p.grad.data
                    
                    #
                    # TODO: Set a more sensible learning rule here,
                    #       using your learning rate schedule and momentum
                    # 
                    p.data -= alpha * v
                    
                    ## Norm Constraints
                    #if(p.data.norm(p=2, dim=1, keepdim=True).max() > 1.5):
                        #print "Max row norm: {0}".format(p.data.norm(p=2, dim=1, keepdim=True).max())
                    #max_len = 1.0
                    #pnorm = p.data.norm(p=2, dim=1, keepdim=True)
                    #pnorm = ((pnorm > max_len).float())*(pnorm/max_len) + ((pnorm <= max_len).float())
                    #p.data = p.data / pnorm.expand_as(p.data)
                    
                    
                    # Zero gradients for the next iteration
                    p.grad.data.zero_()

                if iter_ % log_every == 0:
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%" \
                          .format(iter_, loss.data[0], err_rate)
            val_err_rate = compute_error_rate(model, data_loaders['valid'], cuda)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.clone().cpu() for p in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)
            #print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided above:
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     AffineLayer(784, 700),
     ReLULayer(),
     AffineLayer(700, 600),
     ReLULayer(),
     AffineLayer(600, 500),
     ReLULayer(),
     AffineLayer(500, 10),
     SoftMaxLayer()
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        p.data.normal_(0, 1) 
        p.data = p.data / sqrt(p.data.size()[0])
        #p.data.uniform_(0.0, 0.04)
    elif p.name == 'b':
        p.data.zero_() + 1e-2
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=8*1e-2, cuda=False)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.17 | err rate  4.69%
# Minibatch    200  | loss  0.19 | err rate  6.25%
# Minibatch    300  | loss  0.19 | err rate  4.69%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  4.31% | doing   2 epochs
# ----------------------------------------------------------
# Test error rate: 4.20%
# Minibatch    400  | loss  0.06 | err rate  1.56%
# Minibatch    500  | loss  0.09 | err rate  2.34%
# Minibatch    600  | loss  0.31 | err rate 10.16%
# Minibatch    700  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.91% | doing   4 epochs
# ----------------------------------------------------------
# Test error rate: 2.90%
# Minibatch    800  | loss  0.04 | err rate  0.78%
# Minibatch    900  | loss  0.03 | err rate  0.78%
# Minibatch   1000  | loss  0.07 | err rate  1.56%
# Minibatch   1100  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.68% | doing   5 epochs
# ----------------------------------------------------------
# Test error rate: 2.64%
# Minibatch   1200  | loss  0.03 | err rate  0.78%
# Minibatch   1300  | loss  0.05 | err rate  3.12%
# Minibatch   1400  | loss  0.02 | err rate  0.78%
# Minibatch   1500  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.13% | doing   7 epochs
# ----------------------------------------------------------
# Test error rate: 1.95%
# Minibatch   1600  | loss  0.01 | err rate  0.00%
# Minibatch   1700  | loss  0.03 | err rate  1.56%
# Minibatch   1800  | loss  0.01 | err rate  0.78%
# Minibatch   1900  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.42% | doing   7 epochs
# ----------------------------------------------------------
# Test error rate: 2.14%
# Minibatch   2000  | loss  0.01 | err rate  0.00%
# Minibatch   2100  | loss  0.00 | err rate  0.00%
# Minibatch   2200  | loss  0.00 | err rate  0.00%
# Minibatch   2300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.78% | doing  10 epochs
# ----------------------------------------------------------
# Test error rate: 1.77%
# Minibatch   2400  | loss  0.00 | err rate  0.00%
# Minibatch   2500  | loss  0.00 | err rate  0.00%
# Minibatch   2600  | loss  0.00 | err rate  0.00%
# Minibatch   2700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.69% | doing  11 epochs
# ----------------------------------------------------------
# Test error rate: 1.70%
# Minibatch   2800  | loss  0.00 | err rate  0.00%
# Minibatch   2900  | loss  0.00 | err rate  0.00%
# Minibatch   3000  | loss  0.00 | err rate  0.00%
# Minibatch   3100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.71% | doing  11 epochs
# ----------------------------------------------------------
# Test error rate: 1.72%
# Minibatch   3200  | loss  0.00 | err rate  0.00%
# Minibatch   3300  | loss  0.00 | err rate  0.00%
# Minibatch   3400  | loss  0.00 | err rate  0.00%
# Minibatch   3500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.67% | doing  14 epochs
# ----------------------------------------------------------
# Test error rate: 1.66%
# Minibatch   3600  | loss  0.00 | err rate  0.00%
# Minibatch   3700  | loss  0.00 | err rate  0.00%
# Minibatch   3800  | loss  0.00 | err rate  0.00%
# Minibatch   3900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.65% | doing  16 epochs
# ----------------------------------------------------------
# Test error rate: 1.62%
# Minibatch   4000  | loss  0.00 | err rate  0.00%
# Minibatch   4100  | loss  0.00 | err rate  0.00%
# Minibatch   4200  | loss  0.00 | err rate  0.00%
# Minibatch   4300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.63% | doing  17 epochs
# ----------------------------------------------------------
# Test error rate: 1.60%
# Minibatch   4400  | loss  0.00 | err rate  0.00%
# Minibatch   4500  | loss  0.00 | err rate  0.00%
# Minibatch   4600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.65% | doing  17 epochs
# ----------------------------------------------------------
# Test error rate: 1.59%
# Minibatch   4700  | loss  0.00 | err rate  0.00%
# Minibatch   4800  | loss  0.00 | err rate  0.00%
# Minibatch   4900  | loss  0.00 | err rate  0.00%
# Minibatch   5000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.62% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.58%
# Minibatch   5100  | loss  0.00 | err rate  0.00%
# Minibatch   5200  | loss  0.00 | err rate  0.00%
# Minibatch   5300  | loss  0.00 | err rate  0.00%
# Minibatch   5400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.64% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.59%
# Minibatch   5500  | loss  0.00 | err rate  0.00%
# Minibatch   5600  | loss  0.00 | err rate  0.00%
# Minibatch   5700  | loss  0.00 | err rate  0.00%
# Minibatch   5800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.62% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.62%
# Minibatch   5900  | loss  0.00 | err rate  0.00%
# Minibatch   6000  | loss  0.00 | err rate  0.00%
# Minibatch   6100  | loss  0.00 | err rate  0.00%
# Minibatch   6200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.63% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.58%
# Minibatch   6300  | loss  0.00 | err rate  0.00%
# Minibatch   6400  | loss  0.00 | err rate  0.00%
# Minibatch   6500  | loss  0.00 | err rate  0.00%
# Minibatch   6600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.65% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.59%
# Minibatch   6700  | loss  0.00 | err rate  0.00%
# Minibatch   6800  | loss  0.00 | err rate  0.00%
# Minibatch   6900  | loss  0.00 | err rate  0.00%
# Minibatch   7000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.64% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.60%
# Minibatch   7100  | loss  0.00 | err rate  0.00%
# Minibatch   7200  | loss  0.00 | err rate  0.00%
# Minibatch   7300  | loss  0.00 | err rate  0.00%
# Minibatch   7400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.66% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.59%
# Minibatch   7500  | loss  0.00 | err rate  0.00%
# Minibatch   7600  | loss  0.00 | err rate  0.00%
# Minibatch   7700  | loss  0.00 | err rate  0.00%
# Minibatch   7800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.67% | doing  20 epochs
# ----------------------------------------------------------
# Test error rate: 1.59%
#
# Loading best params on validation set (epoch 13)
#
# Test error rate: 1.58%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
from PIL import Image

def compute_error_rate(model, data_loader, cuda=False):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    for x, y in data_loader:
        if cuda:
            x = x.cuda()
            y = y.cuda()
        x = Variable(x.view(x.size(0), -1), volatile=True)
        y = Variable(y, volatile=True)
        outputs = model.forward(x)
        _, predictions = outputs.data.max(dim=1)
        num_errs += (predictions != y.data).sum()
        num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, cuda=False):
    if cuda:
        for p in model.parameters:
            p.data = p.data.cuda()
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    #
    # velocities = 
    #
    velocities = [torch.zeros(param.size()) for param in model.parameters ]
    if cuda:
        velocities = [v.cuda() for v in velocities]   
    epsilon = 0.5
    
    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']: 
                if cuda:
                    x = x.cuda()
                    y = y.cuda()
                
                ## Data Augmentation
                #x = augment_data(x)
                
                iter_ += 1
                x = Variable(x.view(x.size(0), -1), requires_grad=False)
                y = Variable(y, requires_grad=False)
                
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / out.size(0)

                history['train_losses'].append(loss.data[0])
                history['train_errs'].append(err_rate)
                #
                # TODO: Update learning rate
                # Hint: Use the iteration counter i
                # alpha = TODO
                #
                
                alpha = alpha*0.99996  
                        
                for p, v in zip(model.parameters, velocities):
                    #
                    # TODO: Implement weight decay addition to gradients
                    # p.grad.data += TODO
                    # 
                    if p.name == 'W':
                        p.grad.data += p.grad.data*2
                    #
                    # TODO: Set the momentum constant 
                    # epsilon = TODO
                    #
                    if iter_ == 50:
                        epsilon = 0.999
                    
                    #
                    # TODO: Implement velocity update in momentum
                    # v[...] = TODO
                    #
                    #print p.grad.data.type()
                    v = epsilon*v + p.grad.data
                    
                    #
                    # TODO: Set a more sensible learning rule here,
                    #       using your learning rate schedule and momentum
                    # 
                    p.data -= alpha * v
                    ## Norm Constraints
                    #if(p.data.norm(p=2, dim=1, keepdim=True).max() > 1.0):
                        #print "Max row norm: {0}".format(p.data.norm(p=2, dim=1, keepdim=True).max())
                    #max_len = 1.0
                    #pnorm = p.data.norm(p=2, dim=1, keepdim=True)
                    #pnorm = ((pnorm > max_len).float())*(pnorm/max_len) + ((pnorm <= max_len).float())
                    
                    #p.data = p.data / pnorm.expand_as(p.data)
                    
                    # Zero gradients for the next iteration
                    p.grad.data.zero_()
                
                if iter_ % log_every == 0:
                    print "Minibatch {0: >6}  | loss {1: >5.10f} | err rate {2: >5.10f}%" \
                          .format(iter_, loss.data[0], err_rate)
            val_err_rate = compute_error_rate(model, data_loaders['valid'], cuda)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.clone().cpu() for p in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)
            print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'], cuda)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     DropoutLayer20(),
     AffineLayer(784, 700),
     DropoutLayer(),
     ReLULayer(),
     AffineLayer(700, 600),
     DropoutLayer(),
     ReLULayer(),
     AffineLayer(600, 500),
     DropoutLayer(),
     ReLULayer(),
     AffineLayer(500, 10),
     SoftMaxLayer()
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        p.data.normal_(0, 1) 
        p.data = p.data / sqrt(p.data.size()[0])
        #p.data.uniform_(0.0, 0.04)
    elif p.name == 'b':
        p.data.zero_() + 1e-2
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=1e-1, cuda=False, num_epochs = 1000)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss 0.4454134405 | err rate 12.5000000000%
# Minibatch    200  | loss 0.3616913855 | err rate 13.2812500000%
# Minibatch    300  | loss 0.3914143443 | err rate 10.1562500000%
# -----------------------------------------------------------
# After epoch  1 | valid err rate:  5.56% | doing 1000 epochs
# -----------------------------------------------------------
# Test error rate: 5.90%
# Minibatch    400  | loss 0.3613521457 | err rate 10.9375000000%
# Minibatch    500  | loss 0.1757797450 | err rate 8.5937500000%
# Minibatch    600  | loss 0.1475764513 | err rate 2.3437500000%
# Minibatch    700  | loss 0.3193690777 | err rate 10.9375000000%
# -----------------------------------------------------------
# After epoch  2 | valid err rate:  3.42% | doing 1000 epochs
# -----------------------------------------------------------
# Test error rate: 3.84%
# Minibatch    800  | loss 0.2712845802 | err rate 3.9062500000%
# Minibatch    900  | loss 0.1721550971 | err rate 7.8125000000%
# Minibatch   1000  | loss 0.4383868575 | err rate 13.2812500000%
# Minibatch   1100  | loss 0.1618549526 | err rate 4.6875000000%
# -----------------------------------------------------------
# After epoch  3 | valid err rate:  2.80% | doing 1000 epochs
# -----------------------------------------------------------
# Test error rate: 3.41%
# Minibatch   1200  | loss 0.1289580017 | err rate 6.2500000000%
#
# Loading best params on validation set (epoch 3)
#
# Test error rate: 3.41%

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     AffineLayer(784, 700),
     #DropoutLayer20(),
     ReLULayer(),
        
     AffineLayer(700, 600),
     #DropoutLayer(),
     ReLULayer(),
        
     AffineLayer(600, 10),
     SoftMaxLayer()
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        p.data.normal_(0, 1) 
        p.data = p.data / sqrt(p.data.size()[0]) # sqrt(input size of layer) 
        #p.data.uniform_(0.0, 0.04)
    elif p.name == 'b':
        p.data.zero_() + 1e-2
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=7*1e-2, cuda=False)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.30 | err rate  7.81%
# Minibatch    200  | loss  0.21 | err rate  3.12%
# Minibatch    300  | loss  0.11 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.28% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.05 | err rate  2.34%
# Minibatch    500  | loss  0.12 | err rate  3.12%
# Minibatch    600  | loss  0.19 | err rate  3.12%
# Minibatch    700  | loss  0.07 | err rate  3.12%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.55% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.06 | err rate  1.56%
# Minibatch    900  | loss  0.01 | err rate  0.00%
# Minibatch   1000  | loss  0.03 | err rate  0.78%
# Minibatch   1100  | loss  0.02 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.92% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.04 | err rate  0.78%
# Minibatch   1300  | loss  0.07 | err rate  2.34%
# Minibatch   1400  | loss  0.03 | err rate  1.56%
# Minibatch   1500  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.18% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.01 | err rate  0.00%
# Minibatch   1700  | loss  0.02 | err rate  0.00%
# Minibatch   1800  | loss  0.02 | err rate  0.78%
# Minibatch   1900  | loss  0.05 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  1.97% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.00 | err rate  0.00%
# Minibatch   2100  | loss  0.03 | err rate  0.78%
# Minibatch   2200  | loss  0.01 | err rate  0.00%
# Minibatch   2300  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.93% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.00 | err rate  0.00%
# Minibatch   2500  | loss  0.01 | err rate  0.78%
# Minibatch   2600  | loss  0.00 | err rate  0.00%
# Minibatch   2700  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.76% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.00 | err rate  0.00%
# Minibatch   2900  | loss  0.00 | err rate  0.00%
# Minibatch   3000  | loss  0.00 | err rate  0.00%
# Minibatch   3100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.81% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.00 | err rate  0.00%
# Minibatch   3300  | loss  0.01 | err rate  0.00%
# Minibatch   3400  | loss  0.00 | err rate  0.00%
# Minibatch   3500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.67% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.00 | err rate  0.00%
# Minibatch   3700  | loss  0.00 | err rate  0.00%
# Minibatch   3800  | loss  0.00 | err rate  0.00%
# Minibatch   3900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.67% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.00 | err rate  0.00%
# Minibatch   4100  | loss  0.00 | err rate  0.00%
# Minibatch   4200  | loss  0.00 | err rate  0.00%
# Minibatch   4300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.69% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.00 | err rate  0.00%
# Minibatch   4500  | loss  0.00 | err rate  0.00%
# Minibatch   4600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.67% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.00 | err rate  0.00%
# Minibatch   4800  | loss  0.00 | err rate  0.00%
# Minibatch   4900  | loss  0.00 | err rate  0.00%
# Minibatch   5000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.70% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.00 | err rate  0.00%
# Minibatch   5200  | loss  0.00 | err rate  0.00%
# Minibatch   5300  | loss  0.00 | err rate  0.00%
# Minibatch   5400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.68% | doing  14 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 9)
#
# Test error rate: 1.75%

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %% [markdown]
# ### Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.
